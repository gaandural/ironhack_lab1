# %% [markdown]
# ***Holiday Reccomendations***

# %% [markdown]
# ## the purpose of this notebook is to show my wife's holiday preferences

# %%
her_name = ("Henni")
print("This person's name is", Henni)

# %% [markdown]
# ![Photo%20on%202.02.2021%20at%2016.58.jpg](attachment:Photo%20on%202.02.2021%20at%2016.58.jpg)

# %% [markdown]
# ### her latest holiday destination
# ![abc.svg.png](attachment:abc.svg.png)

# %% [markdown]
# ### Three things she likes doing during holidays:

# %% [markdown]
# 1. Getting into dangerous neighbourhoods
# 2. Staring at people
# 3. Renting a car and driving recklessly
